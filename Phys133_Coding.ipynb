# %%
import numpy as np
import matplotlib.pyplot as plt

lambduh = np.random.standard_exponential((10,100))
avgl = np.average(lambduh)
stdl = np.std(lambduh)
print avgl
print stdl

plt.hist(lambduh,1)
plt.show
# Out:
# 0.9984581451089186
# 0.9956462254121728
# <function matplotlib.pyplot.show>

# %%
l = 10
ui = np.random.random(100)
fi = -10*np.log(1-ui)
print fi

plt.hist(fi)
# Out:
# [ 7.03796271  6.4642488   2.59704799  1.17126936 12.35868445  6.23391505
#   0.41555531  8.02696402  0.38288075  7.08423313 17.49069378  6.30375083
#   2.43785584 30.43999     2.84509369  4.87940444  4.02234479 14.38893596
#   8.65293853  3.6393868  30.5080048   4.66345292  8.30201544 21.55646588
#   1.46137856  1.26355313 17.30009785  0.7898043   7.94315367 18.95405572
#   4.9002221   0.91634572  0.46317628 42.29702423  9.94078379  0.83875738
#   3.80961338 15.06904791  6.08901409  3.29057914  3.3257615  52.08992712
#  23.85706073  6.06813407  4.11612125  6.44078702  6.99980647  5.77801395
#  19.24535172  5.51625254  0.6041242  11.30929833  0.3397176  39.88491328
#   0.85570452 11.74713991 23.98794812  1.67129926  0.56813283 15.37902609
#  10.40189447  8.69963827  0.9714563   3.38184129 10.16654718 27.82933413
#   3.28131375  2.09463355 22.65125181  9.14908035 21.10040097  8.86085369
#  14.42390533  5.39911621 13.70519257  0.79703416  8.02616895 12.38060969
# ...
