# %%
# %matplotlib inline 
import numpy as np 
import matplotlib.pyplot as plt

# %%
#plot for phase vs freq for box B
f = [10,100,500,1000,1500,2000,2500,3000,3500,4000,4500,5000,7000,10000,15000,17500,20000,22500,25000,30000]
p = [0,0,32,50,60,63,72,73,73,73,77,79,86,86,90,89,85,83,90,83]

plt.scatter(f,p)
plt.title("Box B: frequency vs phase")
plt.xlabel("frequency(mV)")
plt.ylabel("phase(deg)")
# Out:
# Text(0, 0.5, 'phase(deg)')
